# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np

# LDA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

from sklearn import datasets

from sklearn.linear_model import LogisticRegression

from sklearn.model_selection import train_test_split

# %%
X,y = datasets.load_iris(True)
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state = 1024)
y_test
# Out:
# array([1, 0, 2, 2, 0, 0, 1, 2, 1, 0, 0, 0, 1, 2, 1, 0, 1, 0, 2, 0, 2, 0,
#        1, 0, 2, 1, 2, 2, 2, 2, 1, 2, 2, 2, 1, 1, 1, 1])

# %%
lr = LogisticRegression()
lr.fit(X_train,y_train)
lr.score(X_test,y_test)
# Out:
# 0.9736842105263158

# %%
lda = LinearDiscriminantAnalysis(n_components=2)
# 监督学习 X ------> y
lda.fit(X,y)
# Out:
# LinearDiscriminantAnalysis(n_components=2, priors=None, shrinkage=None,
#                            solver='svd', store_covariance=False, tol=0.0001)

# %%
# 降维成功
X_lda = lda.transform(X)
X_lda.shape
# Out:
# (150, 2)

# %%
X_train,X_test,y_train,y_test = train_test_split(X_lda,y,random_state = 1024)
lr = LogisticRegression()
lr.fit(X_train,y_train)
lr.score(X_test,y_test)
# Out:
# 0.9473684210526315

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.scatter(X_lda[:,0],X_lda[:,1],c = y)
