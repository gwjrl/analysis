# %%
import numpy as np

import pandas as pd
from pandas import Series,DataFrame

# %%
s = Series(np.random.randn(100000))
s
# Out:
# 0       -0.486279
# 1        0.124742
# 2        0.841410
# 3        1.381907
# 4        0.062832
#            ...
# 99995    1.893475
# 99996   -0.890908
# 99997   -0.177750
# 99998    2.209089
# 99999    0.122534
# Length: 100000, dtype: float64

# %%
s.plot(kind = 'hist',bins = 100,density = True)#density 密度百分比
s.plot(kind = 'kde',color = 'red')

# %%
s.plot(kind = 'kde',color = 'red')

# %%
s2 = Series(np.linspace(0,2*np.pi,100))

s2 = np.sin(s2)

s2.plot(kind = 'line')

# %%
df = DataFrame(np.random.randint(0,150,size = (10,4)),index = list('ABCDEFHIJK'),
               columns=['Python','Math','En','Chinese'])
df
# Out:
#    Python  Math   En  Chinese
# A     108   142   70       10
# B      41    74   90       69
# C      68     8   42      101
# D      27     7   80      111
# E     129    91   56       79
# F       6    47  139        9
# H     100   126   74       25
# I      50    76    5      119
# J     118    17    3       87
# K      52    15  102      141

# %%
df.plot(kind = 'bar')

# %%
df.plot(kind = 'barh')

# %%
df.describe()
# Out:
#            Python  ...     Chinese
# count   10.000000  ...   10.000000
# mean    69.900000  ...   75.100000
# std     41.690527  ...   46.596256
# min      6.000000  ...    9.000000
# 25%     43.250000  ...   36.000000
# 50%     60.000000  ...   83.000000
# 75%    106.000000  ...  108.500000
# max    129.000000  ...  141.000000
#
# [8 rows x 4 columns]

# %%
df.plot(kind = 'box')

# %%
df.plot(kind = 'area')

# %%
df2 = DataFrame(np.random.randint(0,100,size = (4,2)),columns=['Python','Math'])
df2
# Out:
#    Python  Math
# 0      18     1
# 1       5    35
# 2      11    80
# 3      39    61

# %%
df2/df2.sum()
# Out:
#      Python      Math
# 0  0.246575  0.005650
# 1  0.068493  0.197740
# 2  0.150685  0.451977
# 3  0.534247  0.344633

# %%
# pie 绘制的是百分比 饼图
df2.plot(kind = 'pie',subplots = True,autopct = '%0.2f%%')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000235C8F69088>,
# ...
#       dtype=object)

# %%
df2.plot(kind = 'pie',y = ['Math'],autopct = '%0.2f%%')

# %%
df3 = DataFrame(np.random.randint(0,150,size = (100,3)),columns=['Python','En','Chinese'])
df3
# Out:
#     Python   En  Chinese
# 0       28    1      125
# 1       57   49       75
# 2      129   48       31
# 3       53   49       72
# 4       70   35       26
# ..     ...  ...      ...
# 95      57   24      148
# 96      98  103       84
# 97      17    5       58
# 98      11  103      134
# 99     138   83       21
#
# [100 rows x 3 columns]

# %%
df3.plot(kind = 'scatter',x = 'Python',y = 'En')

# %%
df3['Math'] = df3['Python'].map(lambda x : x + np.random.randint(-20,20,size = 1)[0])
df3
# Out:
#     Python   En  Chinese  Math
# 0       28    1      125    41
# 1       57   49       75    63
# 2      129   48       31   134
# 3       53   49       72    66
# 4       70   35       26    69
# ..     ...  ...      ...   ...
# 95      57   24      148    59
# 96      98  103       84    98
# 97      17    5       58    30
# 98      11  103      134    12
# 99     138   83       21   132
#
# [100 rows x 4 columns]

# %%
df3.plot(kind = 'scatter',x = 'Python',y = 'Math')

# %%
df3.plot(kind = 'hexbin',x = 'Python',y = 'Math')

# %%
type(df3.columns.values)
# Out:
# numpy.ndarray

# %%
df3.sort_values(by = 'Python',ascending=False)
# Out:
#     Python   En  Chinese  Math
# 78     145  136       31   161
# 42     144   28       86   157
# 82     143   34       97   139
# 62     142   70       64   153
# 83     142   18      126   148
# ..     ...  ...      ...   ...
# 89      10   31      100    -8
# 15       6  142      111     5
# 71       5   18       44     4
# 9        3   49       32    22
# 72       2   56      114    16
#
# [100 rows x 4 columns]

# %%
n = np.random.randint(0,10,size = 10)
display(n,n.dtype)
# Out:
# array([0, 5, 6, 2, 1, 1, 2, 5, 8, 2])
# dtype('int32')

# %%
df = DataFrame(np.random.randn(150,4))
df
# Out:
#             0         1         2         3
# 0    0.626691 -1.264904 -1.966619 -0.170001
# 1   -0.769160 -0.372721  1.293930  1.380591
# 2   -0.615780  1.075956 -1.266652 -2.198005
# 3    0.086060  0.193900  0.717115  1.088900
# 4   -1.118422  0.283925 -0.223100  0.990739
# ..        ...       ...       ...       ...
# 145  0.413393  0.238075  0.715051 -0.619646
# 146  0.639638 -0.154702 -0.745910  0.656321
# 147 -1.265091  0.926475 -0.640258 -0.735146
# 148  0.614384 -1.966224  0.468868  0.746249
# 149  0.045149 -1.650597  1.005795  0.557227
#
# [150 rows x 4 columns]

# %%
df.dtypes
# Out:
# 0    float64
# 1    float64
# 2    float64
# 3    float64
# dtype: object

# %%
DataFrame([1,2]).dtypes
# Out:
# 0    int64
# dtype: object
